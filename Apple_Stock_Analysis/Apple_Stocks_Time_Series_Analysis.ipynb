# %% [markdown]
# # <center>Apple Inc. Stock Price Analysis and Forecasting</center>

# %% [markdown]
# # Importing Essential Libraries and Tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Bhavanish19/Stocks_Analysis-/main/Apple.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100178  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094952  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087983  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090160   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092774   73449600

# %%
df.tail()
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 10444  2022-05-16  145.550003  147.520004  144.179993  145.539993  145.539993
# 10445  2022-05-17  148.860001  149.770004  146.679993  149.240005  149.240005
# 10446  2022-05-18  146.850006  147.360001  139.899994  140.820007  140.820007
# 10447  2022-05-19  139.880005  141.660004  136.600006  137.350006  137.350006
# 10448  2022-05-20  139.089996  140.699997  132.610001  137.589996  137.589996
#
#           Volume
# 10444   86643800
# 10445   78336300
# 10446  109742900
# 10447  136095600
# 10448  137194600

# %% [markdown]
# As we can see, there are 1918 trading days even though the number of days in this period of time is much larger than 1918. This is because the stock market is not open on weekend and some USA's speacial days such as Independence day, Christmas Day, New Year's Eve and so forth.

# %%
df.shape
# Out:
# (10449, 7)

# %%
df.describe().T.apply(lambda x: x.apply("{0:.3f}".format))
# Out:
#                count           mean            std    min            25%  \
# Open       10449.000         14.528         31.483  0.050          0.283
# High       10449.000         14.687         31.846  0.050          0.289
# Low        10449.000         14.367         31.118  0.049          0.276
# Close      10449.000         14.532         31.493  0.049          0.283
# Adj Close  10449.000         13.898         31.192  0.038          0.235
# Volume     10449.000  331284862.350  338994270.824  0.000  124051200.000
#
#                      50%            75%             max
# Open               0.473         14.532         182.630
# High               0.482         14.619         182.940
# Low                0.464         14.341         179.120
# Close              0.473         14.505         182.010
# Adj Close          0.390         12.556         181.512
# Volume     218747200.000  411499200.000  7421640800.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10449 entries, 0 to 10448
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       10449 non-null  object
#  1   Open       10449 non-null  float64
#  2   High       10449 non-null  float64
#  3   Low        10449 non-null  float64
#  4   Close      10449 non-null  float64
#  5   Adj Close  10449 non-null  float64
#  6   Volume     10449 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 571.6+ KB

# %% [markdown]
# The data type of our Date column should be converted into an appropriate format so that we can work with that variable when visualizing the data.

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values and duplicates so the data seems clear so far.

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# In order to visualize the data on some period, the index of dataframe should be set to Date column.

# %%
df = df.set_index("Date")

# %%
fig = make_subplots(rows=6, cols=1,
                    subplot_titles=("Opening Price", "Closing Price", "Highest Price",
                                    "Lowest Price", "Adjusted Closing Price", "Volume"))

fig.add_trace(go.Scatter(x=df.index, y=df["Open"]), row=1, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df["Close"]), row=2, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df["High"]), row=3, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df["Low"]), row=4, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df["Adj Close"]), row=5, col=1)
fig.add_trace(go.Scatter(x=df.index, y=df["Volume"]), row=6, col=1)
fig.update_layout(showlegend=False, height=1200, width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b91d2647-6d5e-4580-b1c5-81dee5e91d2e" class="plotly-graph-div" style="height:1200px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b91d2647-6d5e-4580-b1c5-81dee5e91d2e")) {                    Plotly.newPlot(                        "b91d2647-6d5e-4580-b1c5-81dee5e91d2e",                        [{"x":["1980-12-12T00:00:00","1980-12-15T00:00:00","1980-12-16T00:00:00","1980-12-17T00:00:00","1980-12-18T00:00:00","1980-12-19T00:00:00","1980-12-22T00:00:00","1980-12-23T00:00:00","1980-12-24T00:00:00","1980-12-26T00:00:00","1980-12-29T00:00:00","1980-12-30T00:00:00","1980-12-31T00:00:00","1981-01-02T00:00:00","1981-01-05T00:00:00","1981-01-06T00:00:00","1981-01-07T00:00:00","1981-01-08T00:00:00","1981-01-09T00:00:00","1981-01-12T00:00:00","1981-01-13T00:00:00","1981-01-14T00:00:00","1981-01-15T00:00:00","1981-01-16T00:00:00","1981-01-19T00:00:00","1981-01-20T00:00:00","1981-01-21T00:00:00","1981-01-22T00:00:00","1981-01-23T00:00:00","1981-01-26T00:00:00","1981-01-27T00:00:00","1981-01-28T00:00:00","1981-01-29T00:00:00","1981-01-30T00:00:00","1981-02-02T00:00:00","1981-02-03T00:00:00","1981-02-04T00:00:00","1981-02-05T00:00:00","1981-02-06T00:00:00","1981-02-09T00:00:00","1981-02-10T00:00:00","1981-02-11T00:00:00","1981-02-12T00:00:00","1981-02-13T00:00:00","1981-02-17T00:00:00","1981-02-18T00:00:00","1981-02-19T00:00:00","1981-02-20T00:00:00","1981-02-23T00:00:00","1981-02-24T00:00:00","1981-02-25T00:00:00","1981-02-26T00:00:00","1981-02-27T00:00:00","1981-03-02T00:00:00","1981-03-03T00:00:00","1981-03-04T00:00:00","1981-03-05T00:00:00","1981-03-06T00:00:00","1981-03-09T00:00:00","1981-03-10T00:00:00","1981-03-11T00:00:00","1981-03-12T00:00:00","1981-03-13T00:00:00","1981-03-16T00:00:00","1981-03-17T00:00:00","1981-03-18T00:00:00","1981-03-19T00:00:00","1981-03-20T00:00:00","1981-03-23T00:00:00","1981-03-24T00:00:00","1981-03-25T00:00:00","1981-03-26T00:00:00","1981-03-27T00:00:00","1981-03-30T00:00:00","1981-03-31T00:00:00","1981-04-01T00:00:00","1981-04-02T00:00:00","1981-04-03T00:00:00","1981-04-06T00:00:00","1981-04-07T00:00:00","1981-04-08T00:00:00","1981-04-09T00:00:00","1981-04-10T00:00:00","1981-04-13T00:00:00","1981-04-14T00:00:00","1981-04-15T00:00:00","1981-04-16T00:00:00","1981-04-20T00:00:00","1981-04-21T00:00:00","1981-04-22T00:00:00","1981-04-23T00:00:00","1981-04-24T00:00:00","1981-04-27T00:00:00","1981-04-28T00:00:00","1981-04-29T00:00:00","1981-04-30T00:00:00","1981-05-01T00:00:00","1981-05-04T00:00:00","1981-05-05T00:00:00","1981-05-06T00:00:00","1981-05-07T00:00:00","1981-05-08T00:00:00","1981-05-11T00:00:00","1981-05-12T00:00:00","1981-05-13T00:00:00","1981-05-14T00:00:00","1981-05-15T00:00:00","1981-05-18T00:00:00","1981-05-19T00:00:00","1981-05-20T00:00:00","1981-05-21T00:00:00","1981-05-22T00:00:00","1981-05-26T00:00:00","1981-05-27T00:00:00","1981-05-28T00:00:00","1981-05-29T00:00:00","1981-06-01T00:00:00","1981-06-02T00:00:00","1981-06-03T00:00:00","1981-06-04T00:00:00","1981-06-05T00:00:00","1981-06-08T00:00:00","1981-06-09T00:00:00","1981-06-10T00:00:00","1981-06-11T00:00:00","1981-06-12T00:00:00","1981-06-15T00:00:00","1981-06-16T00:00:00","1981-06-17T00:00:00","1981-06-18T00:00:00","1981-06-19T00:00:00","1981-06-22T00:00:00","1981-06-23T00:00:00","1981-06-24T00:00:00","1981-06-25T00:00:00","1981-06-26T00:00:00","1981-06-29T00:00:00","1981-06-30T00:00:00","1981-07-01T00:00:00","1981-07-02T00:00:00","1981-07-06T00:00:00","1981-07-07T00:00:00","1981-07-08T00:00:00","1981-07-09T00:00:00","1981-07-10T00:00:00","1981-07-13T00:00:00","1981-07-14T00:00:00","1981-07-15T00:00:00","1981-07-16T00:00:00","1981-07-17T00:00:00","1981-07-20T00:00:00","1981-07-21T00:00:00","1981-07-22T00:00:00","1981-07-23T00:00:00","1981-07-24T00:00:00","1981-07-27T00:00: ...

# %%
fig = go.Figure(data=go.Ohlc(x=df.index, open=df["Open"], high=df["High"], low=df["Low"], close=df["Close"]))
fig.update(layout_xaxis_rangeslider_visible=False)
fig.update_layout(title_text="OHLC Chart", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8637bbc5-f181-46b6-a26c-75aa3d16b19e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8637bbc5-f181-46b6-a26c-75aa3d16b19e")) {                    Plotly.newPlot(                        "8637bbc5-f181-46b6-a26c-75aa3d16b19e",                        [{"close":[0.128348,0.121652,0.112723,0.115513,0.118862,0.126116,0.132254,0.137835,0.145089,0.158482,0.160714,0.156808,0.152344,0.154018,0.15067,0.143973,0.137835,0.135045,0.142299,0.141183,0.136161,0.136719,0.139509,0.138393,0.146763,0.142299,0.145089,0.146763,0.146205,0.143973,0.142857,0.138393,0.133371,0.126116,0.118862,0.123326,0.12779,0.12779,0.128348,0.121652,0.121652,0.117746,0.116629,0.113839,0.116629,0.121652,0.114397,0.108259,0.109933,0.106027,0.112723,0.114397,0.118304,0.118862,0.117188,0.116071,0.115513,0.114397,0.105469,0.100446,0.09654,0.100446,0.09933,0.103237,0.108259,0.114955,0.113839,0.114955,0.11942,0.118862,0.116629,0.114397,0.110491,0.110491,0.109375,0.108259,0.117746,0.118304,0.116071,0.114955,0.120536,0.122768,0.124442,0.124442,0.124442,0.118304,0.111607,0.114955,0.122768,0.127232,0.13058,0.129464,0.128348,0.126116,0.124442,0.126674,0.126674,0.126116,0.125558,0.12221,0.123884,0.125,0.12221,0.12221,0.121652,0.119978,0.122768,0.125,0.122768,0.126674,0.133929,0.140067,0.139509,0.147321,0.147321,0.147879,0.147879,0.140625,0.140625,0.143415,0.141183,0.136161,0.138951,0.140625,0.146763,0.145089,0.144531,0.141741,0.139509,0.138951,0.135045,0.130022,0.132254,0.128906,0.131696,0.130022,0.125558,0.116071,0.114955,0.114955,0.111049,0.112165,0.116629,0.107701,0.09933,0.101563,0.106027,0.108817,0.111607,0.115513,0.107701,0.107143,0.101004,0.103795,0.107143,0.111607,0.107701,0.106027,0.109933,0.111607,0.110491,0.112165,0.115513,0.112723,0.112723,0.112723,0.109375,0.107143,0.103795,0.102121,0.098772,0.09654,0.095424,0.09654,0.089844,0.084263,0.086496,0.084821,0.085379,0.089844,0.089844,0.095424,0.097098,0.092076,0.09096,0.08817,0.08817,0.088728,0.087612,0.084821,0.082589,0.080915,0.078683,0.079241,0.079799,0.075335,0.073661,0.073103,0.063616,0.064174,0.067522,0.06808,0.06808,0.073661,0.075893,0.075335,0.079799,0.082589,0.083147,0.085938,0.085938,0.080915,0.082589,0.081473,0.083147,0.087612,0.087612,0.087054,0.084821,0.084821,0.086496,0.089286,0.08817,0.089286,0.089286,0.08817,0.085938,0.079799,0.080357,0.081473,0.082031,0.084263,0.087054,0.080915,0.079799,0.081473,0.084263,0.084263,0.084821,0.080915,0.080357,0.082031,0.084263,0.083147,0.083147,0.083705,0.082589,0.084821,0.085379,0.083705,0.084263,0.084263,0.083705,0.080915,0.083147,0.087054,0.094308,0.102121,0.097656,0.09933,0.097098,0.097656,0.093192,0.094866,0.098772,0.098772,0.098214,0.093192,0.092076,0.084821,0.088728,0.083147,0.080357,0.079799,0.083705,0.089286,0.09096,0.088728,0.090402,0.092076,0.092634,0.089844,0.086496,0.087054,0.089844,0.09096,0.089844,0.090402,0.090402,0.08817,0.08817,0.082589,0.082589,0.083705,0.082589,0.083705,0.082031,0.083147,0.084263,0.083705,0.082589,0.081473,0.082031,0.081473,0.081473,0.082031,0.082031,0.082031,0.080357,0.074219,0.073103,0.073661,0.072545,0.072545,0.06808,0.067522,0.066406,0.063058,0.06808,0.074219,0.079799,0.078683,0.074219,0.073661,0.072545,0.074219,0.075335,0.075335,0.079241,0.079241,0.079241,0.078683,0.077567,0.078125,0.077567,0.071429,0.071987,0.073103,0.075335,0.073661,0.070313,0.069754,0.068638,0.068638,0.070313,0.06808,0.06529,0.06529,0.065848,0.06808,0.070313,0.069196,0.071429,0.072545,0.071429,0.069196,0.067522,0.06808,0.06529,0.064174,0.063058,0.0625,0.063058,0.063616,0.064174,0.064174,0.063616,0.0625,0.0625,0.061384,0.0625,0.060268,0.058594,0.058594,0.058036,0.05692,0.057478,0.05971,0.05971,0.05971,0.05971,0.058594,0.057478,0.057478,0.05971,0.061384,0.061 ...

# %%
simple_ma = df["Close"].rolling(window=100).mean()

plt.figure(figsize=(14,8))
simple_ma.plot(label="Simple Moving Average")
df["Close"].plot(label="Closing Price")
plt.xticks(rotation=0)
plt.title("Moving Average of Closing Price", size=15)
plt.legend()
plt.show()

# %% [markdown]
# On average, there are 252 trading days in a year so it can be seen that there is a yearly seasonality when I pass in 252 to the parameter "period".

# %%
results = seasonal_decompose(df["Close"], model="multiplicative", period=252)
fig = results.plot()
fig.set_size_inches(12, 8)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Data Splitting

# %% [markdown]
# Since the model we will be using is SARIMA, it takes a little while to train it with a seasonal length like 252. Generally, passing in 4 for quarterly data or 12 for monthly data is common. So, I sum the closing price in a month so that the data has monthly periodicity.

# %%
df = df.resample("MS").sum()

# %% [markdown]
# I preferred to take 80% of the data as train set and the rest 20% as test set.

# %%
df = df.reset_index()

size = int(len(df)*0.8)
train = df.loc[:size,["Date", "Close"]]
test = df.loc[size+1:, ["Date", "Close"]]

df = df.set_index("Date")
train = train.set_index("Date")
test = test.set_index("Date")

# %%
print("Train size:", len(train))
print("Test size:", len(test))
print("Is sum of train and test sizes equal to whole data size:", len(train)+len(test) == df["Close"].shape[0])
# Out:
# Train size: 399
# Test size: 99
# Is sum of train and test sizes equal to whole data size: True

# %% [markdown]
# ### Checking Stationarity

# %% [markdown]
# I define a function for applying the Augmented Dickey-Fuller Test to the data. ADF Test tests the null hypothesis that the time series data has a unit root which means the data is non-stationary.

# %%
def adf_test(data):
    result = adfuller(data)
    print(f'ADF Test Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Number of Lags: {result[2]}')
    print(f'Number of Observations Used: {result[3]}')
    print('Critial Values:')
    for key, value in result[4].items():
        print(f'\t{key}, {value}')

# %% [markdown]
# As you can see, I fail to reject H0 (null) hypothesis. Next step is to difference the data so that time series data has no unit root, hence stationary. Meaning that the data has constant mean and variance over time.

# %%
adf_test(train["Close"])
# Out:
# ADF Test Statistic: 0.5938025985647598
# p-value: 0.9874618735753615
# Number of Lags: 16
# Number of Observations Used: 382
# Critial Values:
# 	1%, -3.4475850438570115
# 	5%, -2.869135963767125
# 	10%, -2.5708164748773332

# %% [markdown]
# ### Removing the Stationarity

# %% [markdown]
# I difference the data by one step.

# %%
differenced_df = train["Close"] - train["Close"].shift()

# %% [markdown]
# After applying the ADF test to the differenced data, I have enough evidence to reject null hypothesis as p value is way too lower than 0.05. In this place, I have seen that differencing the data by one step is enough for making the data stationary so I decide the "d" value as 1.

# %%
adf_test(differenced_df.dropna())
# Out:
# ADF Test Statistic: -4.220632233512685
# p-value: 0.0006078701574850595
# Number of Lags: 17
# Number of Observations Used: 380
# Critial Values:
# 	1%, -3.4476763783532585
# 	5%, -2.869176103659426
# 	10%, -2.570837873961219

# %%
plt.figure(figsize=(12, 6))
differenced_df.plot()
plt.title("First Difference of Closing Price")
plt.show()

# %% [markdown]
# ### Determining the p and q Values

# %% [markdown]
# SARIMA model is comprised of 4 parts; S (Seasonal), p (Autoregressive), d (Integrated) and q (Moving Average). As I already know d value and what kind of seasonality is present in the data, there are one thing left to do: determining p and q values (p for AR part and q for MA). I simply plot the Autocorrelation and Partial Autocorrelation graphs for determining q and p values respectively. Looking at the ACF and PACF plot, it can be observed that first lags of each plot are outside the blue area meaning that those values are statistically significant. So I determine the p and q values as 1.

# %%
fig, ax = plt.subplots(2 ,1, figsize=(10, 12))
plot_acf(differenced_df.iloc[1:], lags=20, ax=ax[0])
plot_pacf(differenced_df.iloc[1:], lags=20, ax=ax[1])
plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# Since the data contains the sum of closing prices in a month, I drop the date August 2022 because I make this project in the August 2022 and we can only calculate the sum of closing prices of this month in September 2022 (which is future).

# %%
if "2022-08-01" in df.index:
    df.drop("2022-08-01", axis=0, inplace=True)
df = df.reset_index(drop=True)  # Reset the index without adding the old index as a column

# %% [markdown]
# I decided to build a SARIMA model because of the yearly seasonality present in the data.

# %%
sarima = sm.tsa.statespace.SARIMAX(df.loc[:73, "Close"], order=(1,1,1), seasonal_order=(1,1,1,12))
results = sarima.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                   74
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                 -43.542
# Date:                            Thu, 22 Feb 2024   AIC                             97.083
# Time:                                    04:43:20   BIC                            107.638
# Sample:                                         0   HQIC                           101.220
#                                              - 74
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7052      0.698      1.010      0.313      -0.663       2.074
# ma.L1         -0.6323      0.764     -0.827      0.408      -2.130       0.866
# ar.S.L12      -0.0017      0.274     -0.006      0.995      -0.538       0.535
# ma.S.L12      -0.9908     18.141     -0.055      0.956     -36.546      34.564
# sigma2         0.1726      3.091      0.056      0.955      -5.887       6.232
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.33   Jarque-Bera (JB):                 0.29
# Prob(Q):                              0.57   Prob(JB):                         0.86
# Heteroskedasticity (H):               0.43   Skew:                            -0.13
# Prob(H) (two-sided):                  0.06   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df["forecast_train"] = results.predict(start=0, end=73)

# %%
df[["Close", "forecast_train"]].plot(figsize=(13,6))
plt.title("Forecasting on Train Set", size=15)
plt.show()

# %%
df["forecast_test"] = results.forecast(17)

# %%
df.tail(20)
# Out:
#             Open         High          Low        Close    Adj Close  \
# 478  2567.269990  2602.040016  2528.049988  2561.090012  2534.057793
# 479  2334.970016  2363.979973  2308.209999  2336.519987  2315.072990
# 480  2797.310014  2829.380013  2766.009972  2800.390007  2775.612329
# 481  2528.920014  2566.330045  2488.599991  2527.700005  2505.335183
# 482  2508.429992  2528.270012  2468.659995  2499.099997  2479.889090
# 483  2808.010020  2839.850006  2769.310005  2803.039986  2782.390427
# 484  2765.120019  2791.139999  2739.770014  2768.070016  2747.678103
# 485  2540.700013  2563.160001  2516.479988  2535.679999  2520.401651
# 486  2848.770020  2874.340025  2832.749999  2859.089991  2842.848124
# 487  3035.980041  3071.300034  3014.309999  3047.930007  3030.615401
# 488  3252.720002  3282.969999  3231.039978  3259.910003  3245.373337
# 489  3129.040009  3149.900009  3091.629974  3114.429993  3101.377319
# 490  3044.399995  3074.789962  3023.049974  3056.839982  3044.028704
# 491  3225.680007  3265.690001  3204.309983  3239.370039  3229.627610
# 492  3809.419999  3863.910050  3767.559997  3818.160003  3807.707123
# 493  3404.030000  3448.959976  3352.790007  3397.229996  3387.929489
# 494  3223.069978  3260.119994  3184.029954  3226.770018  3221.371064
# 495  3790.559983  3844.780015  3747.600008  3802.140014  3796.561891
# 496  3349.580018  3390.370009  3301.660033  3336.419982  3331.525072
# 497  2265.930008  2298.270020  2210.089983  2250.790009  2249.850708
#
#          Volume  forecast_train  forecast_test
# 478  2894666500             NaN            NaN
# 479  2123077300             NaN            NaN
# 480  2322189600             NaN            NaN
# 481  2240262000             NaN            NaN
# 482  1833855600             NaN            NaN
# 483  2650418200             NaN            NaN
# 484  1889857500             NaN            NaN
# 485  1711934900             NaN            NaN
# 486  1606590000             NaN            NaN
# 487  1919035100             NaN            NaN
# 488  1461542800             NaN            NaN
# 489  1797835100             NaN            NaN
# 490  1565079200             NaN            NaN
# 491  1691029000             NaN            NaN
# 492  2444766700             NaN            NaN
# 493  2108446000             NaN            NaN
# 494  1627516300             NaN            NaN
# 495  2180800100             NaN            NaN
# 496  1687635100             NaN            NaN
# 497  1800895900             NaN            NaN

# %%
df[["Close", "forecast_test"]].plot(figsize=(13,6))
plt.title("Forecasting on Test Set", size=15)
plt.show()

# %%
print("Model Performance on Train Set")
print("-"*20)
print("Mean Absolute Error (MAE):", mean_absolute_error(df.loc[:73,"Close"], df.loc[:73,"forecast_train"]))
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(df.loc[:73,"Close"], df.loc[:73,"forecast_train"]))
# Out:
# Model Performance on Train Set
# --------------------
# Mean Absolute Error (MAE): 0.4100199887600725
# Mean Absolute Percentage Error (MAPE): 0.18092041720208832

# %%
# Drop rows with NaN values in 'Close' or 'forecast_test' columns
df_test = df.loc[74:, ['Close', 'forecast_test']].dropna()

print("Model Performance on Test Set")
print("-" * 30)
print("Mean Absolute Error (MAE):", mean_absolute_error(df_test['Close'], df_test['forecast_test']))
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(df_test['Close'], df_test['forecast_test']))
# Out:
# Model Performance on Test Set
# ------------------------------
# Mean Absolute Error (MAE): 2.9036715910719932
# Mean Absolute Percentage Error (MAPE): 0.3627510878973296

# %% [markdown]
# # Forecasting Closing Price From August 2022 to 2023

# %% [markdown]
# It's time to forecast the sum of closing prices of future months from August 2022 to 2023 (excluding January 2023). I create future dates to predict the corresponding closing prices.

# %%
df.index = pd.to_datetime(df.index)

future_dates = [df.index[-1] + pd.DateOffset(months=x) for x in range(1, 6)]
future_df = pd.DataFrame(index=future_dates, columns=df.columns)
df_for_forecast = pd.concat([df, future_df])

df_for_forecast = df_for_forecast.reset_index()
df_for_forecast.rename(columns={"index": "Date"}, inplace=True)

# %%
df_for_forecast["future_forecast"] = results.predict(start=90, end=95)

# %%
df_for_forecast = df_for_forecast.set_index("Date")
df_for_forecast["future_forecast"].tail()
# Out:
# Date
# 1970-02-01 00:00:00.000000497   NaN
# 1970-03-01 00:00:00.000000497   NaN
# 1970-04-01 00:00:00.000000497   NaN
# 1970-05-01 00:00:00.000000497   NaN
# 1970-06-01 00:00:00.000000497   NaN
# Name: future_forecast, dtype: float64

# %%
df_for_forecast[["Close", "future_forecast"]].plot(figsize=(13,6))
plt.title("Forecasting Closing Price From August 2022 to 2023", size=15)
plt.show()
